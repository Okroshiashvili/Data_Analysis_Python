# %% [markdown]
# # Data Visualization
#
# ---
#
#
# "Data visualization (often abbreviated data viz) is an interdisciplinary field that deals with the graphic representation of data..."  [Data visualization](https://en.wikipedia.org/wiki/Data_visualization)
#
# $$
# $$
#
# Data visualization is the graphical representation of information and data. By using visual elements like charts, graphs, and maps, data visualization tools provide an accessible way to see and understand trends, outliers, and patterns in data. Making informative visualizations is one of the most important tasks in data analysis. It may be a part of the exploratory process — for example, to help identify outliers or needed data transformations, or as a way of generating ideas for models. For others, building an interactive visualization for the web may be the end goal.
#
#
#
# $$
# $$
#
# One of the early data viz promoter was [Hans Rosling](https://en.wikipedia.org/wiki/Hans_Rosling) and he was the co-founder of the [Gapminder Foundation](https://www.gapminder.org/). The Gapminder has [incredible tool for data viz](https://www.gapminder.org/tools/#$chart-type=bubbles).
#
#
# $$
# $$
#
# [Hans TED speech is unforgettable](https://www.ted.com/talks/hans_rosling_the_best_stats_you_ve_ever_seen#t-797)
#
#
# And, not only TED speech - [DON'T PANIC — Hans Rosling showing the facts about population](https://www.youtube.com/watch?v=FACK2knC08E)
#
#
# $$
# $$
#
#
#
# [Seeing Theory](https://seeing-theory.brown.edu/)
#
#
#
# $$
# $$
#
#
# ### Lecture outline
#
# ---
#
# * The Datazaurus Dozen
#
#
# * Anscombe’s Quartet
#
#
# * Unstructured Quartet
#
#
# * Line Plots
#
#
# * Bar Charts
#
#
# * Scatter Plots
#
#
# * Histogram
#
#
# * Pie Chart
#
#
# * Box Plot

# %% [markdown]
# #### Resources
#
#
# [List of Data Viz](https://datavizproject.com/)
#
#
# [The Data Visualization Catalogee](https://datavizcatalogue.com/)

# %% [markdown]
# ## The Datazaurus Dozen

# %% [markdown]
# ## Scatter Plots
#
# ---
#
# fsdkfjnsdkfsndgfs

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('05/demos/m4-advanced-plots/athletes.csv', parse_dates=['date_of_birth'])
df.head()
# Out:
#           id nationality     sex date_of_birth  height  weight      sport  \
# 0  736041664         ESP    male    1969-10-17    1.72    64.0  athletics
# 1  532037425         KOR  female    1986-09-23    1.68    56.0    fencing
# 2  435962603         CAN    male    1992-05-27    1.98    79.0  athletics
# 3  521041435         MDA    male    1991-01-02    1.83    80.0  taekwondo
# 4   33922579         NZL    male    1990-11-26    1.81    71.0    cycling
#
#    gold  silver  bronze
# 0     0       0       0
# 1     0       0       0
# 2     0       0       1
# 3     0       0       0
# 4     0       0       0

# %%
f = df[df['sex'] == 'female']
m = df[df['sex'] == 'male']

tennis_f = f[f['sport'] == 'tennis']
tennis_m = m[m['sport'] == 'tennis']

gymnast_f = f[f['sport'] == 'gymnastics']
gymnast_m = m[m['sport'] == 'gymnastics']

# %%
fig, ax = plt.subplots()
plots = [(tennis_f, 'red', 'Tennis, women'), 
         (tennis_m, 'blue', 'Tennis, men'), 
         (gymnast_f, 'orange', 'Gymnastics, women'), 
         (gymnast_m, 'green', 'Gymnastics, men')]
for df, color, label in plots:
    df.plot.scatter(ax=ax, x='weight', y='height', alpha=.25, color=color, label=label)
    
ax.set_xlabel('Weight (kg)')
ax.set_ylabel('Height (m)')
ax.set_title('Heights and Weights of Olympic Athletes');

# %%
fig, ax = plt.subplots()
gymnast_m.plot.scatter(ax=ax, x='height', y='weight', c='gold', colormap='plasma')
fig.tight_layout()

# %% [markdown]
# ## Extra Resources
#
#
# https://towardsdatascience.com/easy-interactive-plot-pandas-plotly-backend-6c9772059515
#
#
# https://towardsdatascience.com/how-to-produce-interactive-matplotlib-plots-in-jupyter-environment-1e4329d71651
#
#
#
# https://medium.com/@ozan/interactive-plots-with-plotly-and-cufflinks-on-pandas-dataframes-af6f86f62d94
#
#
# https://mode.com/blog/python-interactive-plot-libraries/
#
#
# https://realpython.com/pandas-plot-python/
#
#
# https://plotly.com/python/pandas-backend/

# %% [markdown]
# # More Resources - taken from syllabus
#
#
# https://en.wikipedia.org/wiki/Anscombe%27s_quartet
#
#
# https://www.autodesk.com/research/publications/same-stats-different-graphs
#
#
#
# https://plotly.com/python/
#
#
# https://matplotlib.org/gallery/index.html
#
#
# https://matplotlib.org/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py
#
#
#
# https://matplotlib.org/tutorials/index.html
#
#
#
# https://towardsdatascience.com/the-next-level-of-data-visualization-in-python-dd6e99039d5e
#
#
#
# https://guides.library.duke.edu/datavis/vis_types
#
#
# https://towardsdatascience.com/the-simple-yet-practical-data-visualization-codes-bca99971cdb2

# %% [markdown]
# # Resources
#
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
#
#
# https://plotly.com/python/bar-charts/
#
#
# [Convert interactive into static](https://github.com/plotly/Kaleido)

# %% [markdown]
# # Summary
#
# ---
#
# hkbsdfksndlfsfd
